# %%
1+1
# Out:
# 2

# %%
"krishna"
# Out:
# 'krishna'

# %%
# !pip install pandas
# Out:
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.3 MB 2.4 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.3/11.3 MB 2.6 MB/s eta 0:00:04
#    ------ --------------------------------- 1.8/11.3 MB 2.7 MB/s eta 0:00:04
#    --------- ------------------------------ 2.6/11.3 MB 2.9 MB/s eta 0:00:04
#    ------------ --------------------------- 3.4/11.3 MB 3.0 MB/s eta 0:00:03
#    -------------- ------------------------- 4.2/11.3 MB 3.3 MB/s eta 0:00:03
#    ------------------ --------------------- 5.2/11.3 MB 3.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.3/11.3 MB 3.6 MB/s eta 0:00:02
#    ------------------------ --------------- 7.1/11.3 MB 3.7 MB/s eta 0:00:02
# ...
